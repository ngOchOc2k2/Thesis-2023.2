# %%
# !nvidia-smi
# Out:
# Mon Jun 19 20:54:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    45W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CRL-Shaw-48
# Out:
# /content/drive/MyDrive/CRL-Shaw-48

# %%
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/CRL-Shaw-48'

# %%
# !pip3 install transformers
# !pip3 install gpytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 85.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 124.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 92.0 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.0/173.0 kB 25.7 MB/s eta 0:00:00
# ...

# %%
# !python3 run_continual.py --dataname FewRel --encoder_epochs 50  --encoder_lr 2e-5 --prompt_pool_epochs 20  --prompt_pool_lr 1e-4 --classifier_epochs 500 --classifier_lr 5e-5 --replay_epochs 100 --seed 2321
# Out:
# Streaming output truncated to the last 5000 lines.
# train_classifier_epoch_478: 100% 768/768 [00:01<00:00, 420.44it/s, acc=0.999, loss=0.00254]
# train_classifier_epoch_479: 100% 768/768 [00:01<00:00, 420.05it/s, acc=1, loss=0.000499]
# train_classifier_epoch_480: 100% 768/768 [00:01<00:00, 426.76it/s, acc=1, loss=0.000776]
# train_classifier_epoch_481: 100% 768/768 [00:01<00:00, 418.65it/s, acc=0.999, loss=0.00263]
# train_classifier_epoch_482: 100% 768/768 [00:01<00:00, 412.09it/s, acc=1, loss=0.000849]
# train_classifier_epoch_483: 100% 768/768 [00:01<00:00, 416.48it/s, acc=0.999, loss=0.00187]
# train_classifier_epoch_484: 100% 768/768 [00:01<00:00, 423.12it/s, acc=0.999, loss=0.00164]
# train_classifier_epoch_485: 100% 768/768 [00:01<00:00, 426.77it/s, acc=0.999, loss=0.00305]
# train_classifier_epoch_486: 100% 768/768 [00:01<00:00, 425.61it/s, acc=0.999, loss=0.00241]
# train_classifier_epoch_487: 100% 768/768 [00:01<00:00, 427.93it/s, acc=1, loss=0.00168]
# ...

# %%
from google.colab import runtime
runtime.unassign()
